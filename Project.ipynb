# %% [markdown]
# # Hit song predictor

# %%
#Importing the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sc
from Spotify_API.theAPI import sp as api

# %%
#Reading data in csv format
data = pd.read_csv(r"C:\Users\Victor J. Villadiego\OneDrive\Escritorio\dsEAFIT\Programas\Hit_Song_Predictor\data\data.csv")
data_by_artist = pd.read_csv(r"C:\Users\Victor J. Villadiego\OneDrive\Escritorio\dsEAFIT\Programas\Hit_Song_Predictor\data\data_by_artist.csv")
data_by_genres = pd.read_csv(r"C:\Users\Victor J. Villadiego\OneDrive\Escritorio\dsEAFIT\Programas\Hit_Song_Predictor\data\data_by_genres.csv")
data_by_years = pd.read_csv(r"C:\Users\Victor J. Villadiego\OneDrive\Escritorio\dsEAFIT\Programas\Hit_Song_Predictor\data\data_by_year.csv")
data_w_genres = pd.read_csv(r"C:\Users\Victor J. Villadiego\OneDrive\Escritorio\dsEAFIT\Programas\Hit_Song_Predictor\data\data_w_genres.csv")

# %%
#get 5 first rows of the data
data.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
#Using mean, trim_mean and median to get the central tendency of the valence column
print(data["valence"].mean())
print(sc.trim_mean(data["valence"], 0.1))
print(data["valence"].median())

# %%
#Filtering numeric columns
numeric_colums = data.select_dtypes(include='number').columns
df_numeric = data[numeric_colums]
df_numeric

# %%
#the mean for each year excluding the non-numeric columns
df_result = df_numeric.groupby('year').mean().reset_index()
df_result

# %%
#Creando una tabla datos numericos de artistas
df_artists = data.drop(columns=['id', 'name', 'release_date'])

# %%
#EL promedio por año de los datos por cada artista
df_result_artists = df_artists.groupby('artists').mean().reset_index()
df_result_artists

# %%
#Filt for bad bunny data
target_artists = ['Bad Bunny']
data.loc[data['artists'].apply(lambda x: any(artist in x for artist in target_artists))].sort_values(by='popularity', ascending=False)

#data.loc[[0],["valence", "popularity"]]

# %%
#iloc method example
data.iloc[0]

data.loc[[0],["valence", "popularity"]]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
# ...

# %%
data.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# ...

# %%
data["artists"]

# %%
# Example of a song's audio features
song_id = data.loc[0, "id"]
song_audio_features = api.audio_features(song_id)
print(song_audio_features)
# Out:
# [{'danceability': 0.279, 'energy': 0.211, 'key': 10, 'loudness': -20.096, 'mode': 1, 'speechiness': 0.0366, 'acousticness': 0.982, 'instrumentalness': 0.878, 'liveness': 0.665, 'valence': 0.0594, 'tempo': 80.954, 'type': 'audio_features', 'id': '4BJqT0PrAfrxzMOxytFOIz', 'uri': 'spotify:track:4BJqT0PrAfrxzMOxytFOIz', 'track_href': 'https://api.spotify.com/v1/tracks/4BJqT0PrAfrxzMOxytFOIz', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4BJqT0PrAfrxzMOxytFOIz', 'duration_ms': 831667, 'time_signature': 4}]

# %%
song_info = api.track(song_id)
print(song_info)
# Out:
# {'album': {'album_type': 'compilation', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Kekt6CKSo0m5mivKcoH51'}, 'href': 'https://api.spotify.com/v1/artists/0Kekt6CKSo0m5mivKcoH51', 'id': '0Kekt6CKSo0m5mivKcoH51', 'name': 'Sergei Rachmaninoff', 'type': 'artist', 'uri': 'spotify:artist:0Kekt6CKSo0m5mivKcoH51'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'}, 'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of', 'id': '0LyfQWJT6nXafLPZqxe9Of', 'name': 'Various Artists', 'type': 'artist', 'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID
# ...

# %%
# Updating the popularity of a song

filt = data["id"] == "4BJqT0PrAfrxzMOxytFOIz"
song_popularity = api.track(song_id)["popularity"]
data.loc[filt, "popularity"] =  song_popularity

# %%
#Adding a new row to the dataframe
song_features = api.audio_features('7KA4W4McWYRpgf0fWsJZWB')
song_features_dict = song_features[0]
not_interest_keys =  ['type', 'uri', 'track_href', 'analysis_url', 'time_signature']

for key in not_interest_keys:
    del song_features_dict[key]   

data = pd.concat([data, pd.DataFrame([song_features_dict])], ignore_index=True)

# %%
data.tail()
# Out:
#         valence    year  acousticness                artists  danceability  \
# 170649    0.734  2020.0       0.20600           ['Ashnikko']         0.717
# 170650    0.637  2020.0       0.10100            ['MAMAMOO']         0.634
# 170651    0.195  2020.0       0.00998             ['Eminem']         0.671
# 170652    0.642  2020.0       0.13200  ['KEVVO', 'J Balvin']         0.856
# 170653    0.620     NaN       0.37100                    NaN         0.558
#
#         duration_ms  energy  explicit                      id  \
# 170649       150654   0.753       0.0  0OStKKAuXlxA0fMH54Qs6E
# 170650       211280   0.858       0.0  4BZXVFYCb76Q0Klojq4piV
# 170651       337147   0.623       1.0  5SiZJoLXp3WOl3J4C8IK0d
# 170652       189507   0.721       1.0  7HmnJHfs0BkFzX4x8j0hkl
# 170653       180387   0.559       NaN  7KA4W4McWYRpgf0fWsJZWB
#
#         instrumentalness  key  liveness  loudness  mode  \
# 170649          0.000000    7     0.101    -6.020     1
# ...
